# %% [markdown]
# # **Homelessness - Project 1**
# ### Analyzing qualitative and quantitative variables.

# %% [markdown]
# # **Importing Necessary Python Modules**
#
# Python incorporates a variety of open source add-ins called **modules** that add extra features to the basic setup. The name of the modules is after the `import` statement, and the purpose is in a non-code comment after thew hashtag (#).

# %%
import pandas as pd                 #Data analysis
import numpy as np                  #Calculations
import plotly.express as px         #Graphing
import matplotlib.pyplot as plt     #Graphing
from IPython.display import Image   #Display images
import warnings                     #Ignore version warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
# Replace 'image_url' with the URL of the image you want to display
image_url = 'https://endhomelessness.org/wp-content/uploads/2019/03/homelessness-statistics.jpg'

# Display the image
Image(url=image_url)
# Out:
# <img src="https://endhomelessness.org/wp-content/uploads/2019/03/homelessness-statistics.jpg"/>

# %% [markdown]
# # **Context**
#
# The Continuum of Care (CoC) Program is designed to promote communitywide commitment to the goal of ending homelessness; provide funding for efforts by nonprofit providers, and State and local governments to quickly rehouse homeless individuals and families while minimizing the trauma and dislocation caused to homeless individuals, families, and communities by homelessness; promote access to and effect utilization of mainstream programs by homeless individuals and families; and optimize self-sufficiency among individuals and families experiencing homelessness. For more information on the Program, please visit https://www.hudexchange.info/programs/coc/
#
# The U.S. Department of Housing and Urban Development (HUD) provides Point-in-Time (PIT) count reports of sheltered and unsheltered persons experiencing homelessness, by household type and subpopulation. This data is available at the national and state level, and for each CoC. HUD also provides Housing Inventory Count (HIC) reports, which provide a snapshot of a CoC’s inventory of beds and units available on the night designated for the count by program type, and include beds dedicated to serve persons who are homeless as well as persons in Permanent Supportive Housing. This raw data set contains PIT estimates of homelessness, and the corresponding accompanying HIC data from 2021.
#
# Attribution: Adapted from U.S. Department of Housing and Urban Development

# %% [markdown]
# # **About the Dataset**
#
# This dataset contains 100 rows corresponding to a random sample of localities (typically counties or similar large regions) that received Continuum of Care funding from HUD. A total of 21 variables are provided as listed in the table below.

# %% [markdown]
# | Variable Name(s)         | Description |
# |:-------------------------|:--- |
# | CoC Number<br>CoC Name | CoC locality identifier |
# | CoC Category             | Community setting designation: Rural, Urban, etc |
# | Type of Count            | Description of whether fully or partially sheltered individuals (or both) are included |
# | Overall Homeless, 2021   | Total homeless count in all facilities indicated by the “Type of Count” variable |
# | HMIS Participation Rate for Year-Round Beds (ES,TH,SH) | Proportion of facilities in the locality that participate in the Homeless Management Information System (HMIS) |
# | Total Year-Round Beds (ES, TH, SH)<br>Total Year-Round Beds (ES)<br>Total Year-Round Beds (TH)<br>Total Year-Round Beds (SH) | (all types combined)<br>ES = Emergency Shelter<br>TH = Transitional Housing<br>SH = Safe Haven |
# | Total Units for Households with Children (ES, TH, SH)<br>Total Beds for Households with Children (ES, TH, SH) | Number of units and beds designated for households with children |
# | Sheltered ES Homeless 2021 | Estimate of the number of individuals sheltered in an Emergency Facility at the time of the study |
# | Sheltered ES Homeless - Age 18 to 24, 2021 | Estimate of the number of individuals sheltered in an Emergency Facility by age |
# | Sheltered ES Homeless - Female, 2021<br>Sheltered ES Homeless - Male, 2021<br>Sheltered ES Homeless - Trans+, 2021 | Estimate of the number of individuals sheltered in an Emergency Facility by gender |
# | Sheltered ES Homeless - Hispanic/Latino, 2021<br>Sheltered ES Homeless - White, 2021<br>Sheltered ES Homeless - Black or African American, 2021<br>Sheltered ES Homeless - Asian or Pacific Islander<br>Sheltered ES Homeless - American Indian or Alaska Native, 2021<br>Sheltered ES Homeless - Multiple Races, 2021 | Estimate of the number of individuals sheltered in an Emergency Facility by race/ethnicity |

# %% [markdown]
# Let's take a look at the data. To do this, first we import it directly from the url below.

# %% [markdown]
# # **A Snippet of the Data**

# %%
url='https://raw.githubusercontent.com/thamilton562/STAT108_Projects_Students/main/DataSets/Homelessness.csv'
df=pd.read_csv(url)

# %% [markdown]
# Next, we can display the data by *typing the name* of the DataFrame. To ensure we can see all columns, we'll use the *pd.set_option* method.

# %%
# Set display options to show all columns
pd.set_option('display.max_columns', None)
df
# Out:
#    CoC Number                                           CoC Name  \
# 0      LA-505                     Monroe/Northeast Louisiana CoC
# 1      MN-502                  Rochester/Southeast Minnesota CoC
# 2      PA-508                     Scranton/Lackawanna County CoC
# 3      OK-503                      Oklahoma Balance of State CoC
# 4      OH-504                     Youngstown/Mahoning County CoC
# ..        ...                                                ...
# 95     KS-507                        Kansas Balance of State CoC
# 96     CA-507                                   Marin County CoC
# 97     TN-512  Morristown/Blount, Sevier, Campbell, Cocke Cou...
# 98     MA-515                                     Fall River CoC
# 99     CA-526  Amador, Calaveras, Mariposa, Tuolumne Counties...
#
#                CoC Category                   Type of Count  \
# 0         Largely Rural CoC            Sheltered-Only Count
# 1         Largely Rural CoC            Sheltered-Only Count
# 2      Largely Suburban CoC  Sheltered and full unsheltered
# 3         Largely Rural CoC            Sheltered-Only Count
# 4   Other Largely Urban CoC            Sheltered-Only Count
# ..                      ...                             ...
# 95        Largely Rural CoC            Sheltered-Only Count
# 96     Largely Suburban CoC            Sheltered-Only Count
# 97        Largely Rural CoC  Sheltered and full unsheltered
# 98     Largely Suburban CoC  Sheltered and full unsheltered
# 99        Largely Rural CoC            Sheltered-Only Count
#
#     Overall Homeless, 2021  \
# 0                       78
# 1                      419
# 2                      165
# 3                      125
# 4                       62
# ..                     ...
# 95                     783
# 96                     225
# 97                     472
# 98                     324
# 99                     151
#
#     HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 0                                               0.233
# 1                                               0.604
# 2                                               0.839
# 3                                               0.295
# 4                                               0.192
# ..                                                ...
# 95                                              0.162
# 96                                              0.727
# 97                                              0.316
# 98                                              0.877
# 99                                              0.598
#
#     Total Year-Round Beds (ES, TH, SH)  Total Year-Round Beds (ES)  \
# 0                                  133                          69
# 1                                  599                         378
# 2                                  155                          64
# 3                                  149                         135
# 4                                  198                         187
# ..                                 ...                         ...
# 95                                1170                         703
# 96                                 293                         163
# 97                                 133                         117
# 98                                 236                         212
# 99                                 214                         156
#
#     Total Year-Round Beds (TH)  Total Year-Round Beds (SH)  \
# 0                           64                           0
# 1                          221                           0
# 2                           80                          11
# 3                           14                           0
# 4                           11                           0
# ..                         ...                         ...
# 95                         452                          15
# 96                         130                           0
# 97                          16                           0
# 98                          24                           0
# 99                          58                           0
#
#     Total Units for Households with Children (ES, TH, SH)  \
# 0                                                  18
# 1                                                 114
# 2                                                  25
# 3                                                   5
# 4                                                  39
# ..                                                ...
# 95                                                170
# 96                                                 46
# 97                                                 28
# 98                                                 67
# 99                                                 39
#
#     Total Beds for Households with Children (ES, TH, SH)  \
# 0                                                  52
# 1                                                 372
# 2                                                  71
# 3                                                  34
# 4                                                 115
# ..                                                ...
# 95                                                572
# 96                                                142
# 97                                                 65
# 98                                                215
# 99                                                135
#
#     Sheltered ES Homeless, 2021  Sheltered ES Homeless - Age 18 to 24, 2021  \
# 0                            40                                           4
# 1                           261                                          18
# 2                            81                                           5
# 3                           125                                          24
# 4                            56                                           6
# ..                          ...                                         ...
# 95                          430                                          41
# 96                          105                                           6
# 97                          104                                           5
# 98                          223                                          15
# 99                          119                                           2
#
#     Sheltered ES Homeless - Female, 2021  Sheltered ES Homeless - Male, 2021  \
# 0                                     21                                  19
# 1                                    110                                 150
# 2                                     34                                  46
# 3                                     49                                  75
# 4                                     41                                  13
# ..                                   ...                                 ...
# 95                                   153                                 276
# 96                                    41                                  63
# 97                                    61                                  43
# 98                                   122                                 101
# 99                                    66                                  52
#
#     Sheltered ES Homeless - Trans+, 2021  \
# 0                                      0
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      2
# ..                                   ...
# 95                                     1
# 96                                     1
# 97                                     0
# 98                                     0
# 99                                     1
#
#     Sheltered ES Homeless - Hispanic/Latino, 2021  \
# 0                                               0
# 1                                              42
# 2                                               7
# 3                                              52
# 4                                              21
# ..                                            ...
# 95                                             48
# 96                                             28
# 97                                              5
# 98                                             72
# 99                                             21
#
#     Sheltered ES Homeless - White, 2021  \
# 0                                    17
# 1                                   186
# 2                                    61
# 3                                    88
# 4                                    25
# ..                                  ...
# 95                                  307
# 96                                   83
# 97                                   99
# 98                                  135
# 99                                  100
#
#     Sheltered ES Homeless - Black or African American, 2021  \
# 0                                                  19
# 1                                                  51
# 2                                                  17
# 3                                                  25
# 4                                                  19
# ..                                                ...
# 95                                                 60
# 96                                                 16
# 97                                                  1
# 98                                                 80
# 99                                                  2
#
#     Sheltered ES Homeless - Asian or Pacific Islander  \
# 0                                                   0
# 1                                                   9
# 2                                                   2
# 3                                                   1
# 4                                                   1
# ..                                                ...
# 95                                                  7
# 96                                                  1
# 97                                                  1
# 98                                                  1
# 99                                                  1
#
#     Sheltered ES Homeless - American Indian or Alaska Native, 2021  \
# 0                                                   4
# 1                                                   3
# 2                                                   0
# 3                                                   8
# 4                                                   0
# ..                                                ...
# 95                                                 23
# 96                                                  1
# 97                                                  1
# 98                                                  2
# 99                                                  5
#
#     Sheltered ES Homeless - Multiple Races, 2021
# 0                                              0
# 1                                             12
# 2                                              1
# 3                                              3
# 4                                             11
# ..                                           ...
# 95                                            33
# 96                                             4
# 97                                             2
# 98                                             5
# 99                                            11
#
# [100 rows x 23 columns]

# %% [markdown]
# # **INSTRUCTIONS**
#
# * Use Python to analyze the data set and complete each of the following.
# * Replace ellipsis (...) with the relavent names or code.
# * For problems that require a written response, double click the text box to start typing.
# * Reference the 3 tutorials from activity for assistance.
# * Attend office hours if you still need help.

# %% [markdown]
# ## **QUESTION 1**
# Determine whether the four variables below are qualitative or quantitative. If they are quantitative, specify whether they are continuous or discrete.

# %% [markdown]
# | Variable                   | Classification            |
# |:---------------------------|:--------------------------|
# | CoC Category               | Qualitative               |
# | Type of Count              | Qualitative               |
# | HMIS Participation Rate    | Quantitative, continuous  |
# | Sheltered ES Homeless 2021 | Quantitative, discrete    |

# %% [markdown]
# ## **QUESTION 2**
#
# For question 2 you will analyze a qualitative variable. Find your variable based on your last name and use that variable when answering all parts of question 2.
#
# Once you find your variable description, scroll up to "About the Dataset" to find the variable name. Then look at the "Snippet of Data" to get the exact variable name, especially since variable names are case sensitive. You can scroll to the right, if needed.
#
# Construct a frequency table, relative frequency table, and relative frequency bar chart to describe the distribution of your variable. State any fact that jumps out to you.

# %% [markdown]
# | **Last Name** | **Variable Description** |
# |:--------------|:-------------------------|
# | A-L           | CoC Category             |
# | M-Z           | Type of Count            |

# %% [markdown]
# **2a)** Construct a table that contains the frequency and relative frequency distribution for your variable. Round relative frequency to 3 decimal places.

# %% [markdown]
# # **A-L**

# %%
# Define the name of the variable to be analyzed
variable = df['CoC Category']               #variable = df['..']

# Create the frequency table and sort the categories in numerical order.
# .sort_index works here because the category names are numerical.
# rename "count" to "frequency"
freq_table = pd.value_counts(variable)
freq_table = freq_table.rename('Frequency')

# Create the relative frequency table, and rename the counts column to
#   Relative Frequency.
relative_freq_table = freq_table/len(df)                                            #relative_freq_table=freq_table/... HINT: look back at Project 0 or Tutorial 1.
relative_freq_table = relative_freq_table.rename('Relative Frequency').round(3)     # relative_freq_table = relative_freq_table.rename('...').round(...)

# Combine both tables
# axis=1 says to put the tables together as columns
combined_table=pd.concat([freq_table, relative_freq_table], axis=1)                 # combined_table=pd.concat([..., ...], axis=1)

# Print the combined table.
combined_table                                                          # ...
# Out:
#                          Frequency  Relative Frequency
# CoC Category
# Largely Suburban CoC            43                0.43
# Largely Rural CoC               33                0.33
# Other Largely Urban CoC         13                0.13
# Major City CoC                  11                0.11

# %% [markdown]
# # **M-Z**

# %%
# Define the name of the variable to be analyzed
variable = df['Type of Count']               #variable = df['..']

# Create the frequency table and sort the categories in numerical order.
# .sort_index works here because the category names are numerical.
# rename "count" to "frequency"
freq_table2 = pd.value_counts(variable)
freq_table2 = freq_table2.rename('Frequency')

# Create the relative frequency table, and rename the counts column to
#   Relative Frequency.
relative_freq_table2 = freq_table2/len(df)                                            #relative_freq_table=freq_table/... HINT: look back at Project 0 or Tutorial 1.
relative_freq_table2 = relative_freq_table2.rename('Relative Frequency').round(3)     # relative_freq_table = relative_freq_table.rename('...').round(...)

# Combine both tables
combined_table2=pd.concat([freq_table2, relative_freq_table2], axis=1)                 # combined_table=pd.concat([..., ...], axis=1)

# Print the combined table.
combined_table2                                                          # ...
# Out:
#                                    Frequency  Relative Frequency
# Type of Count
# Sheltered-Only Count                      43                0.43
# Sheltered and full unsheltered            33                0.33
# Sheltered and partial unsheltered         24                0.24

# %% [markdown]
# **2b)** Construct a relative frequency bar chart to describe the distribution of chest pain type.

# %% [markdown]
# # **A-L**

# %%
# The argument in (...) tells the system which table to use to make the
#      bar graph. Since we want a relative freqency bar chart, which is the
#      correct label to replace the ellipsis (...) in this code?
dfrf = pd.DataFrame(relative_freq_table)  #dfrf = pd.DataFrame(...)

# Create the bar graph
fig = px.bar(x=dfrf.index,y=dfrf['Relative Frequency'],
             title='Relative Frequency Distribution Bar Chart') #title=...,

# Update axis labels
fig.update_layout(xaxis_title="CoC Category")        #xaxis_title=...
fig.update_layout(yaxis_title="Relative Frequency")             #yaxis_title=...

# Show the bar graph
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bb529b72-9d92-430f-ba17-5fcba6d07d0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb529b72-9d92-430f-ba17-5fcba6d07d0e")) {                    Plotly.newPlot(                        "bb529b72-9d92-430f-ba17-5fcba6d07d0e",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Largely Suburban CoC","Largely Rural CoC","Other Largely Urban CoC","Major City CoC"],"xaxis":"x","y":[0.43,0.33,0.13,0.11],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo", ...

# %% [markdown]
# # **M-Z**

# %%
# The argument in (...) tells the system which table to use to make the
#      bar graph. Since we want a relative freqency bar chart, which is the
#      correct label to replace the ellipsis (...) in this code?
dfrf2 = pd.DataFrame(relative_freq_table2)  #dfrf = pd.DataFrame(...)

# Create the bar graph
fig2 = px.bar(x=dfrf2.index,y=dfrf2['Relative Frequency'],
             title='Relative Frequency Distribution Bar Chart') #title=...,

# Update axis labels
fig2.update_layout(xaxis_title="Type of Count")        #xaxis_title=...
fig2.update_layout(yaxis_title="Relative Frequency")             #yaxis_title=...

# Show the bar graph
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6273e9bd-d307-46a8-9a99-d7bc299f4d27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6273e9bd-d307-46a8-9a99-d7bc299f4d27")) {                    Plotly.newPlot(                        "6273e9bd-d307-46a8-9a99-d7bc299f4d27",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Sheltered-Only Count","Sheltered and full unsheltered","Sheltered and partial unsheltered"],"xaxis":"x","y":[0.43,0.33,0.24],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo" ...

# %% [markdown]
# **2c)** Describe the distribution of your variable.
#
# **A-L:** Localities are most likely to be largely suburban, followed by largely rural, other largely urban, and major city.
#
# **M-Z:** Count types are most likely to be shelter-only, followed by sheltered and full unsheltered, and sheltered and partial unsheltered.

# %% [markdown]
# ## **Question 3**
#
# For question 3 you will analyze a quantitative variable. Find your variable based on your last name and use that variable when answering all parts of question 3.
#
# Once you find your variable description, scroll up to "About the Dataset" to find the variable name. Then look at the "Snippet of Data" to get the exact variable name, especially since variable names are case sensitive.

# %% [markdown]
# | **Last Name** | **Variable Description**               |
# |---------------|----------------------------------------|
# | A-L           | HMIS Participation Rate for Year-Round Beds (ES, TH, SH) |
# | M-Z           | Sheltered ES Homeless, 2021   |

# %% [markdown]
# **3a)** Construct a histogram for your variable. Use number of bins = 18.

# %% [markdown]
# # **A-L**

# %%
# Create the histogram, with the x-axis being the variable specified in the
#   table based on your last name.
fig = px.histogram(x=df['HMIS Participation Rate for Year-Round Beds (ES, TH, SH)'], nbins=18,                         #fig = px.histogram(x=df['...'],nbins = ...,
             title='Histogram of HMIS Participation Rates',                                                            #title='...',
             labels={'x':'Proportion of Facilities That Participate In the Homeless Management Information System'})  #labels={'x':'...')

# Update the vertical axis title.
fig.update_layout(yaxis_title='Frequency')                    #fig.update_layout(yaxis_title='...')

# Print the histogram
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fa0dca9e-9900-4b92-8775-f6f53f27ba85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa0dca9e-9900-4b92-8775-f6f53f27ba85")) {                    Plotly.newPlot(                        "fa0dca9e-9900-4b92-8775-f6f53f27ba85",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Proportion of Facilities That Participate In the Homeless Management Information System=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":18,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.233,0.604,0.839,0.295,0.192,0.628,0.831,0.809,0.624,0.704,0.543,0.843,1.0,0.762,0.857,0.662,0.869,0.905,0.883,0.863,0.549,0.677,0.784,0.857,0.467,0.657,0.508,0.62,0.533,0.778,0.634,0.825,0.765,0.535,0.829,0.739,0.895,0.851,0.841,0.788,0.794,0.871,1.0,0.622,0.766,0.841,0.321,0.344,0.83,1.0,1.0,0.802,0.564,0.432,0.777,0.891,0.193,0.277,0.491,0.656,0.868,0.463,0.837,0.944,0.788,0.166,0.807,0.826,0.756,0.618,0.671,0.944,0.908,0.235,0.623,0.0,0.815,0.978,0.629,0.803,0.741,0.636,0.701,0.93,0.74,0.978,0.843,0.62,0.938,0.377,0.699,0.513,0.395,0.786,0.877,0.162,0.727,0.316,0.877,0.598],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]] ...

# %% [markdown]
# # **M-Z**

# %%
# Create the histogram, with the x-axis being the variable specified in the
#   table based on your last name.
fig = px.histogram(x=df['Sheltered ES Homeless, 2021'],nbins = 18,                           #fig = px.histogram(x=df['...'],nbins = ...,
             title='Histogram of Individuals Sheltered In An Emergency Facility',                  #title='...',
             labels={'x':'Individuals Sheltered In An Emergency Facility'})                        #labels={'x':'...')

# Update the vertical axis title.
fig.update_layout(yaxis_title='Frequency')                       #fig.update_layout(yaxis_title="...")

# Print the histogram
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="789c17d8-e357-4a4a-b999-9c9f76c329dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("789c17d8-e357-4a4a-b999-9c9f76c329dc")) {                    Plotly.newPlot(                        "789c17d8-e357-4a4a-b999-9c9f76c329dc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Individuals Sheltered In An Emergency Facility=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":18,"offsetgroup":"","orientation":"v","showlegend":false,"x":[40,261,81,125,56,278,116,128,2611,128,121,173,54,1479,18,833,1432,950,527,217,24,281,199,439,60,198,27,117,1805,2398,668,185,34,284,353,690,200,173,499,58,529,81,133,76,188,267,274,718,195,323,927,1449,735,61,142,292,528,454,36,14144,2876,79,777,152,76,67,462,227,168,267,4072,397,1217,702,130,2,49,2838,54,1318,343,148,106,25,869,246,465,141,279,169,85,50,131,449,134,430,105,104,223,119],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# **3b)** Construct a boxplot for your variable.

# %% [markdown]
# # **A-L**

# %%
# Create the boxplot, with a title, and specify horizontal axis label.
px.box(x=df['HMIS Participation Rate for Year-Round Beds (ES, TH, SH)'],             #px.box(x=df[...],
       title='Boxplot of HMIS Participations Rates',                 #title='...',
       labels={'x':'Proportion of Facilities That Participate In the Homeless Management Information System'})                     #labels={'x':'...'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="45d06fd5-c579-4a38-a8fe-d1694406c526" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45d06fd5-c579-4a38-a8fe-d1694406c526")) {                    Plotly.newPlot(                        "45d06fd5-c579-4a38-a8fe-d1694406c526",                        [{"alignmentgroup":"True","hovertemplate":"Proportion of Facilities That Participate In the Homeless Management Information System=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[0.233,0.604,0.839,0.295,0.192,0.628,0.831,0.809,0.624,0.704,0.543,0.843,1.0,0.762,0.857,0.662,0.869,0.905,0.883,0.863,0.549,0.677,0.784,0.857,0.467,0.657,0.508,0.62,0.533,0.778,0.634,0.825,0.765,0.535,0.829,0.739,0.895,0.851,0.841,0.788,0.794,0.871,1.0,0.622,0.766,0.841,0.321,0.344,0.83,1.0,1.0,0.802,0.564,0.432,0.777,0.891,0.193,0.277,0.491,0.656,0.868,0.463,0.837,0.944,0.788,0.166,0.807,0.826,0.756,0.618,0.671,0.944,0.908,0.235,0.623,0.0,0.815,0.978,0.629,0.803,0.741,0.636,0.701,0.93,0.74,0.978,0.843,0.62,0.938,0.377,0.699,0.513,0.395,0.786,0.877,0.162,0.727,0.316,0.877,0.598],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"out ...

# %% [markdown]
# # **M-Z**

# %%
px.box(x=df['Sheltered ES Homeless, 2021'],
       title='Boxplot of Individuals Sheltered In An Emergency Facility',
       labels={'x':'Individuals Sheltered In An Emergency Facility'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6914f9f1-d31b-4f45-9ae2-055a19e26e63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6914f9f1-d31b-4f45-9ae2-055a19e26e63")) {                    Plotly.newPlot(                        "6914f9f1-d31b-4f45-9ae2-055a19e26e63",                        [{"alignmentgroup":"True","hovertemplate":"Individuals Sheltered In An Emergency Facility=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[40,261,81,125,56,278,116,128,2611,128,121,173,54,1479,18,833,1432,950,527,217,24,281,199,439,60,198,27,117,1805,2398,668,185,34,284,353,690,200,173,499,58,529,81,133,76,188,267,274,718,195,323,927,1449,735,61,142,292,528,454,36,14144,2876,79,777,152,76,67,462,227,168,267,4072,397,1217,702,130,2,49,2838,54,1318,343,148,106,25,869,246,465,141,279,169,85,50,131,449,134,430,105,104,223,119],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatt ...

# %% [markdown]
# **3c)** Calculate the following summary statistics for your variable: 5 number summary, mean, and standard deviation. Round to three decimal places.

# %%
# Calculate the numerical summaries
# Indicate your variable.
descriptive_stats = df[['HMIS Participation Rate for Year-Round Beds (ES, TH, SH)',
                        'Sheltered ES Homeless, 2021']].describe().round(3)       #descriptive_stats = df[['...']].describe().round(...)

# Print the results.
descriptive_stats                                                                               #...
# Out:
#        HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# count                                            100.000
# mean                                               0.687
# std                                                0.224
# min                                                0.000
# 25%                                                0.589
# 50%                                                0.759
# 75%                                                0.843
# max                                                1.000
#
#        Sheltered ES Homeless, 2021
# count                       100.00
# mean                        604.23
# std                        1532.56
# min                           2.00
# 25%                         105.75
# 50%                         199.50
# 75%                         506.00
# max                       14144.00

# %% [markdown]
# **3d)** Use information from (3a), (3b) and 3(c) to describe your variable in terms of shape, center, spread, and outliers.
# * Use the correct center and the correct spread based on the shape of the distribution.
# * Specify which center and which spread you are using. For ex: Say "The mean is ..." or "The median is ...", rather than "The center is ..."
# * When addressing outliers, if any, list the values of **all** outliers.
# * Include units, if any, for all numbers.
#
# **NOTE:** Students must use the center/spread that match their chosen shape. Skewed/outliers = median/IQR, Symm/no outliers = mean/sd
#
# **A-L:** The distribution of HMIS Participation Rates is skewed left. The outliers are 0, 0.162, and 0.166. The median is 0.759. The IQR is 0.254.
#
# **M-Z:** The distribution of the number of homeless sheltered in emergency facilities (Sheltered ES Homeless, 2021) is skewed right. There 11 outliers; 1217, 1318, 1449, 1479, 1805, 2398, 2611, 2838, 2876, 4072, 14,144 (14.144k) people. The median is 199.5 people (homeless). The IQR is 400.25 people (homeless).

# %% [markdown]
# **3e)** Interpret the standard deviation in context.
#
# **A-L:** The typical HMIS participation rate falls within 0.224 of the mean HMIS participation rate.
#
# **M-Z:** The typical number of homeless sheltered in emergency facilities (Sheltered ES Homeless, 2021) falls within 1532.56 people of the mean.

# %% [markdown]
# **3f)** Interpret the IQR in context.
#
# **A-L:** The range of the middle half (50%) of HMIS participation rates is 0.254.
#
# **M-Z:** The range of the middle half (50%) of Sheltered ES homeless, 2021, is 400.25 people.

# %% [markdown]
# ## **QUESTION 4**
#
# How do major city CoC's and largely rural CoC's compare with respect to whites and blacks/African Americans in emergency shelters?
#
# Calculate the mean number of sheltered ES whites and sheltered ES blacks for major city CoC's and largely rural CoC's. Round to 2 decimal places. Compre the results. Then answer a question about the code.

# %% [markdown]
# **4a)** Calculate and state the number of sheltered ES whites and sheltered ES blacks for major city CoC's and largely rural CoC's.  Round to two decimal places.

# %%
# major_city_means = df[df['CoC Category'] == '...'][['...', '...']].mean().round(...)
# largely_rural_means = df[df['...'] == 'Largely Rural CoC'][['...', '...']].mean().round(...)
major_city_means = df[df['CoC Category'] == 'Major City CoC'][['Sheltered ES Homeless - White, 2021',
                                                               'Sheltered ES Homeless - Black or African American, 2021']].mean().round(2)
largely_rural_means = df[df['CoC Category'] == 'Largely Rural CoC'][['Sheltered ES Homeless - White, 2021',
                                                                     'Sheltered ES Homeless - Black or African American, 2021']].mean().round(2)

# Combine the two table and specify labels.
combined_means = pd.DataFrame({'White': [major_city_means['Sheltered ES Homeless - White, 2021'], largely_rural_means['Sheltered ES Homeless - White, 2021']],
                               'Black': [major_city_means['Sheltered ES Homeless - Black or African American, 2021'], largely_rural_means['Sheltered ES Homeless - Black or African American, 2021']]},
                        index=['Major City Coc', 'Largely Rural CoC'])

# Print the table
combined_means # ...
# Out:
#                      White    Black
# Major City Coc     1385.45  1251.00
# Largely Rural CoC   175.55    36.45

# %% [markdown]
# **4b)** Compare the results for people with and without heart disease.

# %% [markdown]
# Major city CoC's have a larger mean number of white people and a larger mean number of black people in emergency shelters.

# %% [markdown]
# **4c)** In the table below are some snippets of code.

# %% [markdown]
# | **Last Name Initial** | **Code**                    |
# |:-----------------------|:----------------------------------|
# | A-L                    | df['CoC Category'] == 'Major City CoC'  |
# | M-Z                    | df[df['CoC Category'] == 'Major City CoC']|

# %% [markdown]
# Based on your last name, interpret the snippet of code.
#
# **A-L:** Checks to see if the CoC Category is Major City CoC.
#
# **M-Z:** Creates a DataFrame with just Major City Coc's.

# %% [markdown]
# ## **QUESTION 5**
#
# Generate a paragraph of at least 100 words to address one of the following questions. That is, answer only 5a or 5b, but not both.
#
# **5a)** Discuss how analyzing your chosen data set using statistical methods could help you become better prepared for future courses in your major?
#
# ...
#
# --OR--
#
# **5b)** Discuss how analyzing your chosen data set using statistical methods could be instrumental in becoming better prepared for your future career?
#
# ...

# %% [markdown]
# <br><br>
# ### Once you are done and ready to submit, follow the instructions below to save as a PDF and submit to GradeScope.
#
# ### Save as PDF
# 1. Run all code one last time
# 2. File-> Print Preview opens in a new browser window
# 3. Verify you can see all graphs. If not, go back to step 1.
# 4. File -> Print (or ctrl-p/cmnd-p)
# 5. Change destination to PDF (don't save, yet)
# 6. Scroll through preview to make sure you can see your graphs entirely. If not, click Cancel. Make the browser window narrower. Go back to step 4.
# 7. Repeat steps 4-6 until you can see your graphs completely. But do not make them too narrow.
# 8. Save the PDF, taking note of where it is saved.
#
# ### Submit to GradeScope
# 1. Login to the Canvas course
# 2. Click on GradeScope in the course navigation.
# 3. If you see multiple courses in GradeScope, click on the STAT 108 course
# 4. Click on the "Tutorial 2 Practice Upload" assignment
# 5. Click on "Submit Work", select PDF
# 6. Select the PDF you just created
# 7. You need to tell GradeScope which page each problem answer/output is on. You should see a list of problems on the right, and a display of pages (thumbnails) on the right.
# Assign pages to questions by clicking on the question number on the left, then clicking on all pages that question is on.
# 8. After ALL questions have been assigned to their respective page(s), click "Submit"
